# %% [markdown]
# # Correlations

# %%
#import libriaries
import pandas as pd
import numpy as np
import datetime as dt
import pyodbc
import datetime
import plotly.express as px
import sqlite3
import os 
import sqlite3
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

#Destination folder (comment unused directory)
#1 
os.chdir("C:/Users/Lukasz/Documents/GitHub/Analysis-and-forecast-of-stock-exchange-price-based-on-selected-indicators-using-machine-learning/data")
#2
#os.chdir("F:/GitHub/Analysis-and-forecast-of-stock-exchange-price-based-on-selected-indicators-using-machine-learning/data")

# Create your connection.
conn = sqlite3.connect('predictions.db')
c = conn.cursor()

# %% [markdown]
# # SP500 index price correlations

# %%
indicator="SP500"
#Get SQLLite select statement for SP500 index and indicators
df = pd.read_sql_query("""select x."Date", g."Index" as Gold, c19."Index" Covid19, co."Index" as Crude_Oil, 
cr."Index" as Copper, s."Index" as Silver, p."Index" as Platinum, ng."Index" as Natural_Gas,
ip."Index" as Industrial_Production, pa."Index" as Palladium, x."Index" as """+indicator+"""
 from """+indicator+""" as x
  LEFT OUTER JOIN Covid19 as c19 ON x.Date = C19.Date
  LEFT OUTER JOIN Gold as g ON x.Date=g.Date
  LEFT OUTER JOIN Crude_Oil as co ON x.Date=co.Date
  LEFT OUTER JOIN Copper as cr ON x.Date=cr.Date
  LEFT OUTER JOIN Silver as s ON x.Date=s.Date
  LEFT OUTER JOIN Platinum as p ON x.Date=p.Date
  LEFT OUTER JOIN Natural_Gas as ng ON x.Date=ng.Date
  LEFT OUTER JOIN Industrial_Prod as ip ON strftime('%Y-%m', x.Date)=strftime('%Y-%m', ip.Date)
  LEFT OUTER JOIN Palladium as pa ON x.Date=pa.Date
Where x."Index" and g."Index" and co."Index" and cr."Index" and s."Index" and ng."Index" and p."Index"
and ip."Index" and pa."Index" IS NOT NULL
and x.Date < '2020-04-01'
""", conn)
df["Date"] = pd.to_datetime(df["Date"])

df.tail()
# Out:
#            Date     Gold   Covid19  Crude_Oil  Copper  Silver  Platinum  \
# 2492 2020-03-25  1605.45  416881.0      24.49  2.2040  13.965    745.50
# 2493 2020-03-26  1634.80  468092.0      22.60  2.1780  14.415    737.10
# 2494 2020-03-27  1617.30  527839.0      21.51  2.1720  14.315    740.82
# 2495 2020-03-30  1618.30  715377.0      20.09  2.1555  14.055    723.84
# 2496 2020-03-31  1608.95  777187.0      20.48  2.2280  13.930    728.80
#
#       Natural_Gas  Industrial_Production  Palladium    SP500
# 2492         1.80                103.664     2247.6  2475.56
# 2493         1.73                103.664     2226.1  2630.07
# 2494         1.70                103.664     2196.8  2541.47
# 2495         1.65                103.664     2197.6  2626.65
# 2496         1.71                103.664     2304.8  2584.59

# %%
#Make correlation table with heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Change font size
font = {'family' : 'Verdana',
        'weight' : 'bold',
        'size'   : 11}

plt.rc('font', **font)

#Saving df to variable
corr = df.corr()

#Use a mask to plot only part of a matrix
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 9))
    ax = sns.heatmap(corr,
            mask=mask,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True,
            cmap="seismic",
            linewidths=.5
           ,)

#Make correlation basic table
df.corr()
# Out:
#                            Gold   Covid19  Crude_Oil    Copper    Silver  \
# Gold                   1.000000  0.165391   0.461894  0.540390  0.795981
# Covid19                0.165391  1.000000  -0.821807 -0.793628 -0.726239
# Crude_Oil              0.461894 -0.821807   1.000000  0.808247  0.683261
# Copper                 0.540390 -0.793628   0.808247  1.000000  0.805532
# Silver                 0.795981 -0.726239   0.683261  0.805532  1.000000
# Platinum               0.462923 -0.722762   0.815463  0.828080  0.801340
# Natural_Gas           -0.093131 -0.689060   0.577026  0.504719  0.258863
# Industrial_Production -0.169101 -0.656775  -0.413958 -0.532574 -0.561221
# Palladium              0.186781 -0.179127  -0.271204 -0.189316 -0.256601
# SP500                 -0.260548 -0.719717  -0.609251 -0.607067 -0.656352
#
#                        Platinum  Natural_Gas  Industrial_Production  \
# Gold                   0.462923    -0.093131              -0.169101
# Covid19               -0.722762    -0.689060              -0.656775
# Crude_Oil              0.815463     0.577026              -0.413958
# Copper                 0.828080     0.504719              -0.532574
# Silver                 0.801340     0.258863              -0.561221
# Platinum               1.000000     0.584072              -0.785397
# Natural_Gas            0.584072     1.000000              -0.429352
# Industrial_Production -0.785397    -0.429352               1.000000
# Palladium             -0.479912    -0.341965               0.669226
# SP500                 -0.884241    -0.500309               0.908460
#
#                        Palladium     SP500
# Gold                    0.186781 -0.260548
# Covid19                -0.179127 -0.719717
# Crude_Oil              -0.271204 -0.609251
# Copper                 -0.189316 -0.607067
# Silver                 -0.256601 -0.656352
# Platinum               -0.479912 -0.884241
# Natural_Gas            -0.341965 -0.500309
# Industrial_Production   0.669226  0.908460
# Palladium               1.000000  0.752508
# SP500                   0.752508  1.000000

# %%
fig, ((ax1, ax2 ,ax3, ax4), (ax5, ax6,ax7,ax8)) = plt.subplots(nrows=2, ncols=4, sharex=False, sharey=False, figsize=(16,7))

# Subplots
df.plot(x='Date', y='Covid19', legend=False, ax=ax1)
ax1.set_title("Covid19")

df.plot(x='Date', y='Crude_Oil', legend=False, ax=ax2)
ax2.set_title("Crude_Oil")

df.plot(x='Date', y='Copper', legend=False, ax=ax3)
ax3.set_title("Copper")

df.plot(x='Date', y='Silver', legend=False, ax=ax4)
ax4.set_title("Silver")

df.plot(x='Date', y='Platinum', legend=False, ax=ax5)
ax5.set_title("Platinum")

df.plot(x='Date', y='Industrial_Production', legend=False, ax=ax6)
ax6.set_title("Industrial_Production")

df.plot(x='Date', y='Palladium', legend=False, ax=ax7)
ax7.set_title("Palladium")

df.plot(x='Date', y='SP500', legend=False, ax=ax8)
ax8.set_title("SP500")
# If you don't do tight_layout() you'll have weird overlaps
plt.tight_layout()

# %% [markdown]
# # Boening stock prices correlations

# %%
indicator="Boening"
#Get SQLLite select statement Boening stock prices and indicators
df = pd.read_sql_query("""select x."Date", g."Index" as Gold, c19."Index" Covid19, co."Index" as Crude_Oil, 
cr."Index" as Copper, s."Index" as Silver, p."Index" as Platinum, ng."Index" as Natural_Gas,
ip."Index" as Industrial_Production, pa."Index" as Palladium, x."Index" as """+indicator+"""
 from """+indicator+""" as x
  LEFT OUTER JOIN Covid19 as c19 ON x.Date = C19.Date
  LEFT OUTER JOIN Gold as g ON x.Date=g.Date
  LEFT OUTER JOIN Crude_Oil as co ON x.Date=co.Date
  LEFT OUTER JOIN Copper as cr ON x.Date=cr.Date
  LEFT OUTER JOIN Silver as s ON x.Date=s.Date
  LEFT OUTER JOIN Platinum as p ON x.Date=p.Date
  LEFT OUTER JOIN Natural_Gas as ng ON x.Date=ng.Date
  LEFT OUTER JOIN Industrial_Prod as ip ON strftime('%Y-%m', x.Date)=strftime('%Y-%m', ip.Date)
  LEFT OUTER JOIN Palladium as pa ON x.Date=pa.Date
Where x."Index" and g."Index" and co."Index" and cr."Index" and s."Index" and ng."Index" and p."Index"
and ip."Index" and pa."Index" IS NOT NULL
and x.Date < '2020-04-01'
""", conn)

df.tail()
# Out:
#                      Date     Gold   Covid19  Crude_Oil  Copper  Silver  \
# 2492  2020-03-25 00:00:00  1605.45  416881.0      24.49  2.2040  13.965
# 2493  2020-03-26 00:00:00  1634.80  468092.0      22.60  2.1780  14.415
# 2494  2020-03-27 00:00:00  1617.30  527839.0      21.51  2.1720  14.315
# 2495  2020-03-30 00:00:00  1618.30  715377.0      20.09  2.1555  14.055
# 2496  2020-03-31 00:00:00  1608.95  777187.0      20.48  2.2280  13.930
#
#       Platinum  Natural_Gas  Industrial_Production  Palladium  Boening
# 2492    745.50         1.80                103.664     2247.6   158.73
# 2493    737.10         1.73                103.664     2226.1   180.55
# 2494    740.82         1.70                103.664     2196.8   162.00
# 2495    723.84         1.65                103.664     2197.6   152.28
# 2496    728.80         1.71                103.664     2304.8   149.14

# %%
#Make correlation table with heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Change font size
font = {'family' : 'Verdana',
        'weight' : 'bold',
        'size'   : 11}

plt.rc('font', **font)

#Saving df to variable
corr = df.corr()

#Use a mask to plot only part of a matrix
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 9))
    ax = sns.heatmap(corr,
            mask=mask,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True,
            cmap="seismic",
            linewidths=.5
           ,)

#Make correlation basic table
df.corr()
# Out:
#                            Gold   Covid19  Crude_Oil    Copper    Silver  \
# Gold                   1.000000  0.165391   0.461894  0.540390  0.795981
# Covid19                0.165391  1.000000  -0.821807 -0.793628 -0.726239
# Crude_Oil              0.461894 -0.821807   1.000000  0.808247  0.683261
# Copper                 0.540390 -0.793628   0.808247  1.000000  0.805532
# Silver                 0.795981 -0.726239   0.683261  0.805532  1.000000
# Platinum               0.462923 -0.722762   0.815463  0.828080  0.801340
# Natural_Gas           -0.093131 -0.689060   0.577026  0.504719  0.258863
# Industrial_Production -0.169101 -0.656775  -0.413958 -0.532574 -0.561221
# Palladium              0.186781 -0.179127  -0.271204 -0.189316 -0.256601
# Boening               -0.195411 -0.732136  -0.468556 -0.413955 -0.565800
#
#                        Platinum  Natural_Gas  Industrial_Production  \
# Gold                   0.462923    -0.093131              -0.169101
# Covid19               -0.722762    -0.689060              -0.656775
# Crude_Oil              0.815463     0.577026              -0.413958
# Copper                 0.828080     0.504719              -0.532574
# Silver                 0.801340     0.258863              -0.561221
# Platinum               1.000000     0.584072              -0.785397
# Natural_Gas            0.584072     1.000000              -0.429352
# Industrial_Production -0.785397    -0.429352               1.000000
# Palladium             -0.479912    -0.341965               0.669226
# Boening               -0.784315    -0.385716               0.846046
#
#                        Palladium   Boening
# Gold                    0.186781 -0.195411
# Covid19                -0.179127 -0.732136
# Crude_Oil              -0.271204 -0.468556
# Copper                 -0.189316 -0.413955
# Silver                 -0.256601 -0.565800
# Platinum               -0.479912 -0.784315
# Natural_Gas            -0.341965 -0.385716
# Industrial_Production   0.669226  0.846046
# Palladium               1.000000  0.748445
# Boening                 0.748445  1.000000

# %% [markdown]
# # Exxon mobil stock prices correlations

# %%
indicator="Exxon_mobil"
#Get SQLLite select statement Exxon_mobil stock prices and indicators
df = pd.read_sql_query("""select x."Date", g."Index" as Gold, c19."Index" Covid19, co."Index" as Crude_Oil, 
cr."Index" as Copper, s."Index" as Silver, p."Index" as Platinum, ng."Index" as Natural_Gas,
ip."Index" as Industrial_Production, pa."Index" as Palladium, x."Index" as """+indicator+"""
 from """+indicator+""" as x
  LEFT OUTER JOIN Covid19 as c19 ON x.Date = C19.Date
  LEFT OUTER JOIN Gold as g ON x.Date=g.Date
  LEFT OUTER JOIN Crude_Oil as co ON x.Date=co.Date
  LEFT OUTER JOIN Copper as cr ON x.Date=cr.Date
  LEFT OUTER JOIN Silver as s ON x.Date=s.Date
  LEFT OUTER JOIN Platinum as p ON x.Date=p.Date
  LEFT OUTER JOIN Natural_Gas as ng ON x.Date=ng.Date
  LEFT OUTER JOIN Industrial_Prod as ip ON strftime('%Y-%m', x.Date)=strftime('%Y-%m', ip.Date)
  LEFT OUTER JOIN Palladium as pa ON x.Date=pa.Date
Where x."Index" and g."Index" and co."Index" and cr."Index" and s."Index" and ng."Index" and p."Index"
and ip."Index" and pa."Index" IS NOT NULL
and x.Date < '2020-04-01'
""", conn)

df.tail()
# Out:
#                      Date     Gold   Covid19  Crude_Oil  Copper  Silver  \
# 2492  2020-03-25 00:00:00  1605.45  416881.0      24.49  2.2040  13.965
# 2493  2020-03-26 00:00:00  1634.80  468092.0      22.60  2.1780  14.415
# 2494  2020-03-27 00:00:00  1617.30  527839.0      21.51  2.1720  14.315
# 2495  2020-03-30 00:00:00  1618.30  715377.0      20.09  2.1555  14.055
# 2496  2020-03-31 00:00:00  1608.95  777187.0      20.48  2.2280  13.930
#
#       Platinum  Natural_Gas  Industrial_Production  Palladium  Exxon_mobil
# 2492    745.50         1.80                103.664     2247.6        37.29
# 2493    737.10         1.73                103.664     2226.1        38.82
# 2494    740.82         1.70                103.664     2196.8        36.95
# 2495    723.84         1.65                103.664     2197.6        37.50
# 2496    728.80         1.71                103.664     2304.8        37.97

# %%
#Make correlation table with heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Change font size
font = {'family' : 'Verdana',
        'weight' : 'bold',
        'size'   : 11}

plt.rc('font', **font)

#Saving df to variable
corr = df.corr()

#Use a mask to plot only part of a matrix
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 9))
    ax = sns.heatmap(corr,
            mask=mask,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True,
            cmap="seismic",
            linewidths=.5
           ,)

#Make correlation basic table
df.corr()
# Out:
#                            Gold   Covid19  Crude_Oil    Copper    Silver  \
# Gold                   1.000000  0.165391   0.461894  0.540390  0.795981
# Covid19                0.165391  1.000000  -0.821807 -0.793628 -0.726239
# Crude_Oil              0.461894 -0.821807   1.000000  0.808247  0.683261
# Copper                 0.540390 -0.793628   0.808247  1.000000  0.805532
# Silver                 0.795981 -0.726239   0.683261  0.805532  1.000000
# Platinum               0.462923 -0.722762   0.815463  0.828080  0.801340
# Natural_Gas           -0.093131 -0.689060   0.577026  0.504719  0.258863
# Industrial_Production -0.169101 -0.656775  -0.413958 -0.532574 -0.561221
# Palladium              0.186781 -0.179127  -0.271204 -0.189316 -0.256601
# Exxon_mobil           -0.017257 -0.739311   0.357024  0.061961  0.137210
#
#                        Platinum  Natural_Gas  Industrial_Production  \
# Gold                   0.462923    -0.093131              -0.169101
# Covid19               -0.722762    -0.689060              -0.656775
# Crude_Oil              0.815463     0.577026              -0.413958
# Copper                 0.828080     0.504719              -0.532574
# Silver                 0.801340     0.258863              -0.561221
# Platinum               1.000000     0.584072              -0.785397
# Natural_Gas            0.584072     1.000000              -0.429352
# Industrial_Production -0.785397    -0.429352               1.000000
# Palladium             -0.479912    -0.341965               0.669226
# Exxon_mobil            0.138500     0.148803               0.173144
#
#                        Palladium  Exxon_mobil
# Gold                    0.186781    -0.017257
# Covid19                -0.179127    -0.739311
# Crude_Oil              -0.271204     0.357024
# Copper                 -0.189316     0.061961
# Silver                 -0.256601     0.137210
# Platinum               -0.479912     0.138500
# Natural_Gas            -0.341965     0.148803
# Industrial_Production   0.669226     0.173144
# Palladium               1.000000    -0.318048
# Exxon_mobil            -0.318048     1.000000

# %% [markdown]
# # Arch Coal stock prices correlations

# %%
indicator="Arch_Coal"
#Get SQLLite select statement Arch Coal stock prices and indicators
df = pd.read_sql_query("""SELECT x."Date", 
g."Index" as Gold, 
c19."Index" Covid19, 
co."Index" as Crude_Oil, 
cr."Index" as Copper, 
s."Index" as Silver, 
p."Index" as Platinum, 
ng."Index" as Natural_Gas,
ip."Index" as Industrial_Production, 
pa."Index" as Palladium, x."Index" as """+indicator+"""
 FROM """+indicator+""" as x
  LEFT OUTER JOIN Covid19 as c19 ON x.Date = C19.Date
  LEFT OUTER JOIN Gold as g ON x.Date=g.Date
  LEFT OUTER JOIN Crude_Oil as co ON x.Date=co.Date
  LEFT OUTER JOIN Copper as cr ON x.Date=cr.Date
  LEFT OUTER JOIN Silver as s ON x.Date=s.Date
  LEFT OUTER JOIN Platinum as p ON x.Date=p.Date
  LEFT OUTER JOIN Natural_Gas as ng ON x.Date=ng.Date
  LEFT OUTER JOIN Industrial_Prod as ip ON strftime('%Y-%m', x.Date)=strftime('%Y-%m', ip.Date)
  LEFT OUTER JOIN Palladium as pa ON x.Date=pa.Date
WHERE x."Index" and g."Index" and co."Index" and cr."Index" and s."Index" and ng."Index" and p."Index"
and ip."Index" and pa."Index" IS NOT NULL
and x.Date < '2020-04-01'
""", conn)

df.tail()
# Out:
#                     Date     Gold   Covid19  Crude_Oil  Copper  Silver  \
# 846  2020-03-25 00:00:00  1605.45  416881.0      24.49  2.2040  13.965
# 847  2020-03-26 00:00:00  1634.80  468092.0      22.60  2.1780  14.415
# 848  2020-03-27 00:00:00  1617.30  527839.0      21.51  2.1720  14.315
# 849  2020-03-30 00:00:00  1618.30  715377.0      20.09  2.1555  14.055
# 850  2020-03-31 00:00:00  1608.95  777187.0      20.48  2.2280  13.930
#
#      Platinum  Natural_Gas  Industrial_Production  Palladium  Arch_Coal
# 846    745.50         1.80                103.664     2247.6      33.24
# 847    737.10         1.73                103.664     2226.1      30.91
# 848    740.82         1.70                103.664     2196.8      27.32
# 849    723.84         1.65                103.664     2197.6      27.38
# 850    728.80         1.71                103.664     2304.8      28.90

# %%
#Make correlation table with heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Change font size
font = {'family' : 'Verdana',
        'weight' : 'bold',
        'size'   : 11}

plt.rc('font', **font)

#Saving df to variable
corr = df.corr()

#Use a mask to plot only part of a matrix
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 9))
    ax = sns.heatmap(corr,
            mask=mask,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True,
            cmap="seismic",
            linewidths=.5
           ,)

#Make correlation basic table
df.corr()
# Out:
#                            Gold   Covid19  Crude_Oil    Copper    Silver  \
# Gold                   1.000000  0.165391  -0.208924 -0.148948  0.340396
# Covid19                0.165391  1.000000  -0.821807 -0.793628 -0.726239
# Crude_Oil             -0.208924 -0.821807   1.000000  0.519673 -0.202604
# Copper                -0.148948 -0.793628   0.519673  1.000000 -0.012528
# Silver                 0.340396 -0.726239  -0.202604 -0.012528  1.000000
# Platinum               0.037760 -0.722762  -0.060670  0.219692  0.824148
# Natural_Gas           -0.677749 -0.689060   0.158055  0.208571 -0.227264
# Industrial_Production  0.317853 -0.656775   0.536684  0.191164 -0.412764
# Palladium              0.876266 -0.179127  -0.083667 -0.131840  0.033209
# Arch_Coal             -0.420789 -0.759269   0.698079  0.515552 -0.358831
#
#                        Platinum  Natural_Gas  Industrial_Production  \
# Gold                   0.037760    -0.677749               0.317853
# Covid19               -0.722762    -0.689060              -0.656775
# Crude_Oil             -0.060670     0.158055               0.536684
# Copper                 0.219692     0.208571               0.191164
# Silver                 0.824148    -0.227264              -0.412764
# Platinum               1.000000     0.005606              -0.515569
# Natural_Gas            0.005606     1.000000              -0.090000
# Industrial_Production -0.515569    -0.090000               1.000000
# Palladium             -0.194151    -0.567661               0.556141
# Arch_Coal             -0.123079     0.377196               0.452336
#
#                        Palladium  Arch_Coal
# Gold                    0.876266  -0.420789
# Covid19                -0.179127  -0.759269
# Crude_Oil              -0.083667   0.698079
# Copper                 -0.131840   0.515552
# Silver                  0.033209  -0.358831
# Platinum               -0.194151  -0.123079
# Natural_Gas            -0.567661   0.377196
# Industrial_Production   0.556141   0.452336
# Palladium               1.000000  -0.273479
# Arch_Coal              -0.273479   1.000000

# %% [markdown]
# # Peabody Energy stock prices correlations

# %%
indicator="Peabody"
#Get SQLLite select statement Peabody stock prices and indicators
df = pd.read_sql_query("""SELECT x."Date", 
g."Index" as Gold, 
c19."Index" Covid19, 
co."Index" as Crude_Oil, 
cr."Index" as Copper, 
s."Index" as Silver, 
p."Index" as Platinum, 
ng."Index" as Natural_Gas,
ip."Index" as Industrial_Production, 
pa."Index" as Palladium, x."Index" as """+indicator+"""
 FROM """+indicator+""" as x
  LEFT OUTER JOIN Covid19 as c19 ON x.Date = C19.Date
  LEFT OUTER JOIN Gold as g ON x.Date=g.Date
  LEFT OUTER JOIN Crude_Oil as co ON x.Date=co.Date
  LEFT OUTER JOIN Copper as cr ON x.Date=cr.Date
  LEFT OUTER JOIN Silver as s ON x.Date=s.Date
  LEFT OUTER JOIN Platinum as p ON x.Date=p.Date
  LEFT OUTER JOIN Natural_Gas as ng ON x.Date=ng.Date
  LEFT OUTER JOIN Industrial_Prod as ip ON strftime('%Y-%m', x.Date)=strftime('%Y-%m', ip.Date)
  LEFT OUTER JOIN Palladium as pa ON x.Date=pa.Date
WHERE x."Index" and g."Index" and co."Index" and cr."Index" and s."Index" and ng."Index" and p."Index"
and ip."Index" and pa."Index" IS NOT NULL
and x.Date < '2020-04-01'
""", conn)

df.tail()
# Out:
#                     Date     Gold   Covid19  Crude_Oil  Copper  Silver  \
# 725  2020-03-25 00:00:00  1605.45  416881.0      24.49  2.2040  13.965
# 726  2020-03-26 00:00:00  1634.80  468092.0      22.60  2.1780  14.415
# 727  2020-03-27 00:00:00  1617.30  527839.0      21.51  2.1720  14.315
# 728  2020-03-30 00:00:00  1618.30  715377.0      20.09  2.1555  14.055
# 729  2020-03-31 00:00:00  1608.95  777187.0      20.48  2.2280  13.930
#
#      Platinum  Natural_Gas  Industrial_Production  Palladium  Peabody
# 725    745.50         1.80                103.664     2247.6     3.12
# 726    737.10         1.73                103.664     2226.1     2.84
# 727    740.82         1.70                103.664     2196.8     2.81
# 728    723.84         1.65                103.664     2197.6     2.70
# 729    728.80         1.71                103.664     2304.8     2.90

# %%
#Make correlation table with heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Change font size
font = {'family' : 'Verdana',
        'weight' : 'bold',
        'size'   : 11}

plt.rc('font', **font)

#Save df to variable
corr = df.corr()

#Use a mask to plot only part of a matrix
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 9))
    ax = sns.heatmap(corr,
            mask=mask,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True,
            cmap="coolwarm",
            linewidths=.5
           ,)

#Make correlation basic table
df.corr()
# Out:
#                            Gold   Covid19  Crude_Oil    Copper    Silver  \
# Gold                   1.000000  0.165391  -0.340238 -0.347966  0.493625
# Covid19                0.165391  1.000000  -0.821807 -0.793628 -0.726239
# Crude_Oil             -0.340238 -0.821807   1.000000  0.482920 -0.130491
# Copper                -0.347966 -0.793628   0.482920  1.000000  0.150246
# Silver                 0.493625 -0.726239  -0.130491  0.150246  1.000000
# Platinum               0.182029 -0.722762   0.035575  0.449921  0.811534
# Natural_Gas           -0.686378 -0.689060   0.194584  0.308334 -0.257622
# Industrial_Production  0.121977 -0.656775   0.496139 -0.142144 -0.302587
# Palladium              0.869731 -0.179127  -0.236617 -0.417039  0.196742
# Peabody               -0.805475 -0.731062   0.622074  0.627743 -0.337639
#
#                        Platinum  Natural_Gas  Industrial_Production  \
# Gold                   0.182029    -0.686378               0.121977
# Covid19               -0.722762    -0.689060              -0.656775
# Crude_Oil              0.035575     0.194584               0.496139
# Copper                 0.449921     0.308334              -0.142144
# Silver                 0.811534    -0.257622              -0.302587
# Platinum               1.000000    -0.024330              -0.405810
# Natural_Gas           -0.024330     1.000000              -0.012742
# Industrial_Production -0.405810    -0.012742               1.000000
# Palladium             -0.049305    -0.596390               0.397825
# Peabody               -0.069698     0.573005               0.016283
#
#                        Palladium   Peabody
# Gold                    0.869731 -0.805475
# Covid19                -0.179127 -0.731062
# Crude_Oil              -0.236617  0.622074
# Copper                 -0.417039  0.627743
# Silver                  0.196742 -0.337639
# Platinum               -0.049305 -0.069698
# Natural_Gas            -0.596390  0.573005
# Industrial_Production   0.397825  0.016283
# Palladium               1.000000 -0.776626
# Peabody                -0.776626  1.000000
