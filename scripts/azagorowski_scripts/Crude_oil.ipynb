# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import os 
# %matplotlib inline

# %% [markdown]
# # CRUDE OIL PRICE

# %%
#Put path to the folder with data source
os.chdir('F:/GitHub/Analysis-and-forecast-of-stock-exchange-price-based-on-selected-indicators-using-machine-learning/data/azagorowski_data')

# %%
#Display options
pd.set_option('display.min_rows', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 1000)

# %%
#Import data, skip description rows, use columns: date & value
crude_oil = pd.read_csv('wti-crude-oil-prices-10-year-daily-chart.csv',
                     skiprows=14,
                     usecols=['date',' value'])

#Convert column type to date time
crude_oil["date"] = pd.to_datetime(crude_oil["date"])

#Select price between 2010-01-01 and 2020-03-24
filter = (crude_oil['date'] >= '2010-01-01') & (crude_oil['date'] < '2020-03-25')
crude_oil = crude_oil[filter]

#Rename columns
crude_oil = crude_oil.rename(columns={'date': 'Date', ' value': 'Price'})

#Change index column for "Date"
crude_oil.index = crude_oil['Date']

#Delete "Date" column that is not an index
crude_oil = crude_oil.drop(columns=['Date'])

#Display Data Frame
crude_oil.head()
# Out:
#             Price
# Date
# 2010-03-29  82.17
# 2010-03-30  82.37
# 2010-03-31  83.76
# 2010-04-01  84.87
# 2010-04-05  86.62

# %% [markdown]
# ## Crude oil price chart

# %%
plt.style.use('fivethirtyeight')
crude_oil.plot(title="Crude Oil price chart from 2010-01-01 to 2020-03-25 - source: \"www.macrotrends.net\"",
            figsize=(15,10),grid=True,fontsize=16)

# %% [markdown]
# # SAUDI ARABIA CRUDE OIL PRODUCTION

# %%
#Import data, skip description rows, use columns: date & value
crude_oil_saudi = pd.read_csv('saudi-arabia-crude-oil-production-chart.csv',
                     skiprows=14,
                     usecols=['date',' value'])

#Convert column type to date time
crude_oil_saudi["date"] = pd.to_datetime(crude_oil_saudi["date"])

#Select price between 2010-01-01 and 2020-03-24
filter = (crude_oil_saudi['date'] >= '2010-01-01') & (crude_oil_saudi['date'] < '2020-03-25')
crude_oil_saudi = crude_oil_saudi[filter]

#Rename columns
crude_oil_saudi = crude_oil_saudi.rename(columns={'date': 'Date', ' value': '[millions of barrels]'})

#Change index column for "Date"
crude_oil_saudi.index = crude_oil_saudi['Date']

#Delete "Date" column that is not an index
crude_oil_saudi = crude_oil_saudi.drop(columns=['Date'])

#Display Data Frame
crude_oil_saudi.head()
# Out:
#             [millions of barrels]
# Date
# 2010-01-01                    8.2
# 2010-02-01                    8.4
# 2010-03-01                    8.5
# 2010-04-01                    8.7
# 2010-05-01                    8.7

# %%
plt.style.use('fivethirtyeight')
crude_oil_saudi.plot(title="Saudi Arabia Crude Oil production chart from 2010-01 to 2020-02 - source: \"www.macrotrends.net\"",
            figsize=(15,10),grid=True,fontsize=16)

# %% [markdown]
# # U.S. CRUDE OIL PRODUCTION

# %%
#Import data, skip description rows, use columns: date & value
crude_oil_us = pd.read_csv('us-crude-oil-production-historical-chart.csv',
                     skiprows=14,
                     usecols=['date',' value'])

#Convert column type to date time
crude_oil_us["date"] = pd.to_datetime(crude_oil_us["date"])

#Select price between 2010-01-01 and 2020-03-24
filter = (crude_oil_us['date'] >= '2010-01-01') & (crude_oil_us['date'] < '2020-03-25')
crude_oil_us = crude_oil_us[filter]

#Rename columns
crude_oil_us = crude_oil_us.rename(columns={'date': 'Date', ' value': '[millions of barrels]'})

#Change index column for "Date"
crude_oil_us.index = crude_oil_us['Date']

#Delete "Date" column that is not an index
crude_oil_us = crude_oil_us.drop(columns=['Date'])

#Display Data Frame
crude_oil_us.head()
# Out:
#             [millions of barrels]
# Date
# 2010-01-01                 5403.0
# 2010-02-01                 5510.0
# 2010-03-01                 5489.0
# 2010-04-01                 5522.0
# 2010-05-01                 5320.0

# %%
plt.style.use('fivethirtyeight')
crude_oil_us.plot(title="U.S. Crude Oil production chart from 2010-01 to 2020-02 - source: \"www.macrotrends.net\"",
            figsize=(15,10),grid=True,fontsize=16)
